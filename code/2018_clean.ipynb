# %%
import os
import pandas as pd
import numpy as np

# %%
path = os.getcwd()
df = pd.read_csv(path + '\..\\raw_data\\World Happiness\\2018.csv')
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# 1             1.582                    0.861                         0.686
# 2             1.590                    0.868                         0.683
# 3             1.644                    0.914                         0.677
# 4             1.549                    0.927                         0.660
# ..              ...                      ...                           ...
# 151           1.073                    0.343                         0.244
# 152           0.991                    0.381                         0.481
# 153           0.608                    0.177                         0.112
# 154           0.000                    0.010                         0.305
# 155           0.627                    0.145                         0.065
#
#      Generosity  Perceptions of corruption
# 0         0.202                      0.393
# 1         0.286                      0.340
# 2         0.284                      0.408
# 3         0.353                      0.138
# 4         0.256                      0.357
# ..          ...                        ...
# 151       0.083                      0.064
# 152       0.270                      0.097
# 153       0.224                      0.106
# 154       0.218                      0.038
# 155       0.149                      0.076
#
# [156 rows x 9 columns]

# %%
df.rename(columns = {'Overall rank':'Happiness Rank','Score':'Happiness Score','GDP per capita':'Economy (GDP per Capita)','Healthy life expectancy': 'Health (Life Expectancy)','Perceptions of corruption':'Trust (Government Corruption)','Country or region':'Country'}, inplace = True)
df
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.632
# 1                 2                    Norway            7.594
# 2                 3                   Denmark            7.555
# 3                 4                   Iceland            7.495
# 4                 5               Switzerland            7.487
# ..              ...                       ...              ...
# 151             152                     Yemen            3.355
# 152             153                  Tanzania            3.303
# 153             154               South Sudan            3.254
# 154             155  Central African Republic            3.083
# 155             156                   Burundi            2.905
#
#      Economy (GDP per Capita)  Social support  Health (Life Expectancy)  \
# 0                       1.305           1.592                     0.874
# 1                       1.456           1.582                     0.861
# 2                       1.351           1.590                     0.868
# 3                       1.343           1.644                     0.914
# 4                       1.420           1.549                     0.927
# ..                        ...             ...                       ...
# 151                     0.442           1.073                     0.343
# 152                     0.455           0.991                     0.381
# 153                     0.337           0.608                     0.177
# 154                     0.024           0.000                     0.010
# 155                     0.091           0.627                     0.145
#
#      Freedom to make life choices  Generosity  Trust (Government Corruption)
# 0                           0.681       0.202                          0.393
# 1                           0.686       0.286                          0.340
# 2                           0.683       0.284                          0.408
# 3                           0.677       0.353                          0.138
# 4                           0.660       0.256                          0.357
# ..                            ...         ...                            ...
# 151                         0.244       0.083                          0.064
# 152                         0.481       0.270                          0.097
# 153                         0.112       0.224                          0.106
# 154                         0.305       0.218                          0.038
# 155                         0.065       0.149                          0.076
#
# [156 rows x 9 columns]

# %%
def swap_columns(df, col1, col2):
    col_list = list(df.columns)
    x, y = col_list.index(col1), col_list.index(col2)
    col_list[y], col_list[x] = col_list[x], col_list[y]
    df = df[col_list]
    return df

#swap points and rebounds columns
df = swap_columns(df, 'Country','Happiness Rank')
df = swap_columns(df, 'Trust (Government Corruption)','Generosity')
df
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                     Finland               1            7.632
# 1                      Norway               2            7.594
# 2                     Denmark               3            7.555
# 3                     Iceland               4            7.495
# 4                 Switzerland               5            7.487
# ..                        ...             ...              ...
# 151                     Yemen             152            3.355
# 152                  Tanzania             153            3.303
# 153               South Sudan             154            3.254
# 154  Central African Republic             155            3.083
# 155                   Burundi             156            2.905
#
#      Economy (GDP per Capita)  Social support  Health (Life Expectancy)  \
# 0                       1.305           1.592                     0.874
# 1                       1.456           1.582                     0.861
# 2                       1.351           1.590                     0.868
# 3                       1.343           1.644                     0.914
# 4                       1.420           1.549                     0.927
# ..                        ...             ...                       ...
# 151                     0.442           1.073                     0.343
# 152                     0.455           0.991                     0.381
# 153                     0.337           0.608                     0.177
# 154                     0.024           0.000                     0.010
# 155                     0.091           0.627                     0.145
#
#      Freedom to make life choices  Trust (Government Corruption)  Generosity
# 0                           0.681                          0.393       0.202
# 1                           0.686                          0.340       0.286
# 2                           0.683                          0.408       0.284
# 3                           0.677                          0.138       0.353
# 4                           0.660                          0.357       0.256
# ..                            ...                            ...         ...
# 151                         0.244                          0.064       0.083
# 152                         0.481                          0.097       0.270
# 153                         0.112                          0.106       0.224
# 154                         0.305                          0.038       0.218
# 155                         0.065                          0.076       0.149
#
# [156 rows x 9 columns]

# %%
df=df.drop(columns='Generosity')
df
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                     Finland               1            7.632
# 1                      Norway               2            7.594
# 2                     Denmark               3            7.555
# 3                     Iceland               4            7.495
# 4                 Switzerland               5            7.487
# ..                        ...             ...              ...
# 151                     Yemen             152            3.355
# 152                  Tanzania             153            3.303
# 153               South Sudan             154            3.254
# 154  Central African Republic             155            3.083
# 155                   Burundi             156            2.905
#
#      Economy (GDP per Capita)  Social support  Health (Life Expectancy)  \
# 0                       1.305           1.592                     0.874
# 1                       1.456           1.582                     0.861
# 2                       1.351           1.590                     0.868
# 3                       1.343           1.644                     0.914
# 4                       1.420           1.549                     0.927
# ..                        ...             ...                       ...
# 151                     0.442           1.073                     0.343
# 152                     0.455           0.991                     0.381
# 153                     0.337           0.608                     0.177
# 154                     0.024           0.000                     0.010
# 155                     0.091           0.627                     0.145
#
#      Freedom to make life choices  Trust (Government Corruption)
# 0                           0.681                          0.393
# 1                           0.686                          0.340
# 2                           0.683                          0.408
# 3                           0.677                          0.138
# 4                           0.660                          0.357
# ..                            ...                            ...
# 151                         0.244                          0.064
# 152                         0.481                          0.097
# 153                         0.112                          0.106
# 154                         0.305                          0.038
# 155                         0.065                          0.076
#
# [156 rows x 8 columns]

# %%
nan_df = df[df.isna().any(axis=1)]
display(nan_df.head())

df = df.dropna(how='any')
df
# Out:
#                  Country  Happiness Rank  Happiness Score  \
# 19  United Arab Emirates              20            6.774
#
#     Economy (GDP per Capita)  Social support  Health (Life Expectancy)  \
# 19                     2.096           0.776                      0.67
#
#     Freedom to make life choices  Trust (Government Corruption)
# 19                         0.284                            NaN
#                       Country  Happiness Rank  Happiness Score  \
# 0                     Finland               1            7.632
# 1                      Norway               2            7.594
# 2                     Denmark               3            7.555
# 3                     Iceland               4            7.495
# 4                 Switzerland               5            7.487
# ..                        ...             ...              ...
# 151                     Yemen             152            3.355
# 152                  Tanzania             153            3.303
# 153               South Sudan             154            3.254
# 154  Central African Republic             155            3.083
# 155                   Burundi             156            2.905
#
#      Economy (GDP per Capita)  Social support  Health (Life Expectancy)  \
# 0                       1.305           1.592                     0.874
# 1                       1.456           1.582                     0.861
# 2                       1.351           1.590                     0.868
# 3                       1.343           1.644                     0.914
# 4                       1.420           1.549                     0.927
# ..                        ...             ...                       ...
# 151                     0.442           1.073                     0.343
# 152                     0.455           0.991                     0.381
# 153                     0.337           0.608                     0.177
# 154                     0.024           0.000                     0.010
# 155                     0.091           0.627                     0.145
#
#      Freedom to make life choices  Trust (Government Corruption)
# 0                           0.681                          0.393
# 1                           0.686                          0.340
# 2                           0.683                          0.408
# 3                           0.677                          0.138
# 4                           0.660                          0.357
# ..                            ...                            ...
# 151                         0.244                          0.064
# 152                         0.481                          0.097
# 153                         0.112                          0.106
# 154                         0.305                          0.038
# 155                         0.065                          0.076
#
# [155 rows x 8 columns]

# %%
region_df = pd.read_csv(path + '\..\\raw_data\\World Happiness\\2015.csv')

# Merge the DataFrames based on "Country" column
df = pd.merge(df, region_df[['Country', 'Region']], on='Country', how='left')

# Reorder the columns with "Region" in the third column position
df = df[df.columns[:2].tolist() + ['Region'] + df.columns[2:-1].tolist()]

df
# Out:
#                       Country  Happiness Rank  \
# 0                     Finland               1
# 1                      Norway               2
# 2                     Denmark               3
# 3                     Iceland               4
# 4                 Switzerland               5
# ..                        ...             ...
# 150                     Yemen             152
# 151                  Tanzania             153
# 152               South Sudan             154
# 153  Central African Republic             155
# 154                   Burundi             156
#
#                               Region  Happiness Score  \
# 0                     Western Europe            7.632
# 1                     Western Europe            7.594
# 2                     Western Europe            7.555
# 3                     Western Europe            7.495
# 4                     Western Europe            7.487
# ..                               ...              ...
# 150  Middle East and Northern Africa            3.355
# 151               Sub-Saharan Africa            3.303
# 152                              NaN            3.254
# 153               Sub-Saharan Africa            3.083
# 154               Sub-Saharan Africa            2.905
#
#      Economy (GDP per Capita)  Social support  Health (Life Expectancy)  \
# 0                       1.305           1.592                     0.874
# 1                       1.456           1.582                     0.861
# 2                       1.351           1.590                     0.868
# 3                       1.343           1.644                     0.914
# 4                       1.420           1.549                     0.927
# ..                        ...             ...                       ...
# 150                     0.442           1.073                     0.343
# 151                     0.455           0.991                     0.381
# 152                     0.337           0.608                     0.177
# 153                     0.024           0.000                     0.010
# 154                     0.091           0.627                     0.145
#
#      Freedom to make life choices  Trust (Government Corruption)
# 0                           0.681                          0.393
# 1                           0.686                          0.340
# 2                           0.683                          0.408
# 3                           0.677                          0.138
# 4                           0.660                          0.357
# ..                            ...                            ...
# 150                         0.244                          0.064
# 151                         0.481                          0.097
# 152                         0.112                          0.106
# 153                         0.305                          0.038
# 154                         0.065                          0.076
#
# [155 rows x 9 columns]

# %%
# Filter the DataFrame to get rows with missing values in the "Region" column
missing_region_countries = df[df['Region'].isna()]['Country'].tolist()

# Print the countries with missing region
for country in missing_region_countries:
    print(country)
# Out:
# Trinidad & Tobago
# Belize
# Northern Cyprus
# Somalia
# Namibia
# South Sudan

# %%
# Create a dictionary mapping countries to their respective regions
region_mapping = {
    'Trinidad & Tobago': 'Latin America and Caribbean',
    'Belize': 'Latin America and Caribbean',
    'Northern Cyprus': 'Middle East and Northern Africa',
    'Somalia': 'Sub-Saharan Africa',
    'Namibia': 'Sub-Saharan Africa',
    'South Sudan': 'Sub-Saharan Africa'
}

# Add the missing "Region" values for the specified countries
for country, region in region_mapping.items():
    df.loc[df['Country'] == country, 'Region'] = region

# %%
# Move "Happiness Rank" to the first column
df = df[['Happiness Rank'] + df.columns.drop('Happiness Rank').tolist()]

# %%
df.to_csv(path + "/../clean_data/2018.csv", index=False)
